# %% [markdown]
# # Форматы данных (1)

# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`. Воспользовавшись модулем `json`, преобразуйте содержимое файла в соответствующие объекты python. Выведите на экран информацию о первых 3 пользователях.

# %%
# !pip install json
import json

# %%
with open('contributors_sample.json') as j:
  dfrm = json.load(j)
print(dfrm)
# Out:
# [{'username': 'uhebert', 'name': 'Lindsey Nguyen', 'sex': 'F', 'address': '01261 Cameron Spring\nTaylorfurt, AK 97791', 'mail': 'jsalazar@gmail.com', 'jobs': ['Energy engineer', 'Engineer, site', 'Environmental health practitioner', 'Biomedical scientist', 'Jewellery designer'], 'id': 35193}, {'username': 'vickitaylor', 'name': 'Cheryl Lewis', 'sex': 'F', 'address': '66992 Welch Brooks\nMarshallshire, ID 56004', 'mail': 'bhudson@gmail.com', 'jobs': ['Music therapist', 'Volunteer coordinator', 'Designer, interior/spatial'], 'id': 91970}, {'username': 'sheilaadams', 'name': 'Julia Allen', 'sex': 'F', 'address': 'Unit 1632 Box 2971\nDPO AE 23297', 'mail': 'darren44@yahoo.com', 'jobs': ['Management consultant', 'Engineer, structural', 'Lecturer, higher education', 'Theatre manager', 'Designer, textile'], 'id': 1848091}, {'username': 'nicole82', 'name': 'Gina Stevens', 'sex': 'F', 'address': '9880 Michelle Bridge\nNew Kimberlybury, WY 02583', 'mail': 'stevensonsarah@hotmail.com', 'jobs': 
# ...

# %%
#var 1
print(dfrm[0], '\n**************\n', dfrm[1], '\n***************\n', dfrm[2])
# Out:
# {'username': 'uhebert', 'name': 'Lindsey Nguyen', 'sex': 'F', 'address': '01261 Cameron Spring\nTaylorfurt, AK 97791', 'mail': 'jsalazar@gmail.com', 'jobs': ['Energy engineer', 'Engineer, site', 'Environmental health practitioner', 'Biomedical scientist', 'Jewellery designer'], 'id': 35193}
# **************
#  {'username': 'vickitaylor', 'name': 'Cheryl Lewis', 'sex': 'F', 'address': '66992 Welch Brooks\nMarshallshire, ID 56004', 'mail': 'bhudson@gmail.com', 'jobs': ['Music therapist', 'Volunteer coordinator', 'Designer, interior/spatial'], 'id': 91970}
# ***************
#  {'username': 'sheilaadams', 'name': 'Julia Allen', 'sex': 'F', 'address': 'Unit 1632 Box 2971\nDPO AE 23297', 'mail': 'darren44@yahoo.com', 'jobs': ['Management consultant', 'Engineer, structural', 'Lecturer, higher education', 'Theatre manager', 'Designer, textile'], 'id': 1848091}

# %%
#var 2
with open('contributors_sample.json') as f:
    dfrm = json.load(f)

for contributor in dfrm[:3]:
    print(f"id: {contributor['id']}", f"\nникнейм: {contributor['username']}", f"\nимя: {contributor['name']}", 
          f"\nпол: {contributor['sex']}", f"\nадрес: {contributor['address']}", f"\nпочта: {contributor['mail']}",
          f"\nработа: {contributor['jobs']}", '\n**********')
# Out:
# id: 35193
# никнейм: uhebert
# имя: Lindsey Nguyen
# пол: F
# адрес: 01261 Cameron Spring
# Taylorfurt, AK 97791
# почта: jsalazar@gmail.com
# работа: ['Energy engineer', 'Engineer, site', 'Environmental health practitioner', 'Biomedical scientist', 'Jewellery designer']
# **********
# id: 91970
# никнейм: vickitaylor
# имя: Cheryl Lewis
# пол: F
# адрес: 66992 Welch Brooks
# Marshallshire, ID 56004
# почта: bhudson@gmail.com
# работа: ['Music therapist', 'Volunteer coordinator', 'Designer, interior/spatial']
# **********
# id: 1848091
# никнейм: sheilaadams
# имя: Julia Allen
# пол: F
# адрес: Unit 1632 Box 2971
# DPO AE 23297
# почта: darren44@yahoo.com
# работа: ['Management consultant', 'Engineer, structural', 'Lecturer, higher education', 'Theatre manager', 'Designer, textile']
# **********

# %% [markdown]
# 1.2 Выведите уникальные почтовые домены, содержащиеся в почтовых адресах людей

# %%
poch = set()
for j in dfrm:
  poch.add(j['mail'][j['mail'].find('@')::])
print(poch)
# Out:
# {'@hotmail.com', '@yahoo.com', '@gmail.com'}

# %% [markdown]
# 1.3 Напишите функцию, которая по `username` ищет человека и выводит информацию о нем. Если пользователь с заданным `username` отсутствует, возбудите исключение `ValueError`

# %%
def search(username):
    if username not in [i['username'] for i in dfrm]:
        raise ValueError('Нет такого пользователя!')
    for i in dfrm:
        if i['username']==username:
            return i
            
search(input('Введите имя:\n'))
# Out:
# Введите имя:
# uhebert
# {'username': 'uhebert',
#  'name': 'Lindsey Nguyen',
#  'sex': 'F',
#  'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#  'mail': 'jsalazar@gmail.com',
#  'jobs': ['Energy engineer',
#   'Engineer, site',
#   'Environmental health practitioner',
#   'Biomedical scientist',
#   'Jewellery designer'],
#  'id': 35193}

# %% [markdown]
# 1.4 Посчитайте, сколько мужчин и женщин присутсвует в этом наборе данных.

# %%
mal = 0
dev = 0
for usrs in dfrm:
    if usrs['sex'] == 'M':
        mal += 1
    if usrs['sex'] == 'F':
        dev += 1
print(mal,dev)
# Out:
# 2064 2136

# %% [markdown]
# 1.5 Создайте `pd.DataFrame` `contributors`, имеющий столбцы `id`, `username` и `sex`.

# %%
import pandas as pd
contributors = pd.read_json('contributors_sample.json')[['id', 'username', 'sex']]
contributors.head()
# Out:
#         id     username sex
# 0    35193      uhebert   F
# 1    91970  vickitaylor   F
# 2  1848091  sheilaadams   F
# 3    50969     nicole82   F
# 4   676820       jean67   M

# %% [markdown]
# 1.6 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Объедините `recipes` с таблицей `contributors` с сохранением строк в том случае, если информация о человеке отсутствует в JSON-файле. Для скольких человек информация отсутствует?

# %%
rcp = pd.read_csv('recipes_sample.csv')
dfrm10 = pd.merge(contributors, rcp, how = 'right', left_on = 'id', right_on = 'contributor_id')
dfrm10.head(3)
# Out:
#       id_x     username  sex                                   name   id_y  \
# 0  35193.0      uhebert    F  george s at the cove  black bean soup  44123
# 1  91970.0  vickitaylor    F     healthy for them  yogurt popsicles  67664
# 2      NaN          NaN  NaN           i can t believe it s spinach  38798
#
#    minutes  contributor_id   submitted  n_steps  \
# 0       90           35193  2002-10-25      NaN
# 1       10           91970  2003-07-26      NaN
# 2       30            1533  2002-08-29      NaN
#
#                                          description  n_ingredients
# 0  an original recipe created by chef scott meska...           18.0
# 1  my children and their friends ask for my homem...            NaN
# 2            these were so go, it surprised even me.            8.0

# %%
dfrm10['username'].isna().value_counts()[1]
# Out:
# 15059

# %% [markdown]
# ### pickle

# %% [markdown]
# 2.1 На основе файла `contributors_sample.json` создайте словарь следующего вида:
# ```
# {
#     должность: [список username людей, занимавших эту должность]
# }
# ```

# %%
jobs = set(sum([k['jobs'] for k in dfrm], []))
dolz = {j: [] for j in jobs}

for k in dfrm: 
    for j in jobs: 
        if j in k['jobs']: 
            dolz[j].append(k['username'])
print(dolz)
# Out:
# {'Mudlogger': ['amanda04', 'smithjennifer', 'hmoran', 'michaelsheppard', 'ogonzalez', 'michelle51', 'courtneystein', 'palmermatthew', 'ninamartinez', 'tlamb', 'adkinsangela', 'mckeesusan', 'courtneyanderson', 'zwinters', 'daniel71', 'martha42', 'owensalisha', 'vsims', 'hwright', 'gpearson', 'holly45', 'lmathews'], 'Surveyor, planning and development': ['christina73', 'wdavis', 'leslie63', 'garytorres', 'brittany14', 'duranclaire', 'tyler76', 'chasemartin', 'dnewman', 'sandra00', 'christopher67', 'patrick01', 'lrivers', 'gregory04', 'vthomas', 'hansenjason', 'vdelgado', 'wilsonjames', 'roberttravis', 'paularnold', 'michaelluna', 'lisagentry', 'martinezmark', 'bgarcia', 'youngangela', 'kathryngriffin', 'kmoore', 'christophermartin', 'brent34', 'ljohnson', 'jorgewood', 'lambertjimmy'], 'Curator': ['harrissandra', 'amorales', 'pattersonstephanie', 'brooksanthony', 'cwashington', 'mcmahonleslie', 'jeffery66', 'wvelasquez', 'nholland', 'michelle00', 'jerryyoung', 'gaustin', 'marissa82', 't
# ...

# %% [markdown]
# 2.2 Сохраните результаты в файл `job_people.pickle` и в файл `job_people.json` с использованием форматов pickle и JSON соответственно. Сравните объемы получившихся файлов. При сохранении в JSON укажите аргумент `indent`.

# %%
import pickle

with open('job_people.pickle', 'wb') as z:
    pickle.dump(dolz, z, protocol=pickle.HIGHEST_PROTOCOL)
with open('job_people.json', 'w') as z:
    json.dump(dolz, z, indent = 1)

# %%
from os import stat
stat('job_people.json').st_size, stat('job_people.pickle').st_size
# Out:
# (284400, 132095)

# %% [markdown]
# 2.3 Считайте файл `job_people.pickle` и продемонстрируйте, что данные считались корректно.

# %%
with open('job_people.pickle','rb') as z:
  prosm = pickle.load(z)
print(prosm)
# Out:
# {'Mudlogger': ['amanda04', 'smithjennifer', 'hmoran', 'michaelsheppard', 'ogonzalez', 'michelle51', 'courtneystein', 'palmermatthew', 'ninamartinez', 'tlamb', 'adkinsangela', 'mckeesusan', 'courtneyanderson', 'zwinters', 'daniel71', 'martha42', 'owensalisha', 'vsims', 'hwright', 'gpearson', 'holly45', 'lmathews'], 'Surveyor, planning and development': ['christina73', 'wdavis', 'leslie63', 'garytorres', 'brittany14', 'duranclaire', 'tyler76', 'chasemartin', 'dnewman', 'sandra00', 'christopher67', 'patrick01', 'lrivers', 'gregory04', 'vthomas', 'hansenjason', 'vdelgado', 'wilsonjames', 'roberttravis', 'paularnold', 'michaelluna', 'lisagentry', 'martinezmark', 'bgarcia', 'youngangela', 'kathryngriffin', 'kmoore', 'christophermartin', 'brent34', 'ljohnson', 'jorgewood', 'lambertjimmy'], 'Curator': ['harrissandra', 'amorales', 'pattersonstephanie', 'brooksanthony', 'cwashington', 'mcmahonleslie', 'jeffery66', 'wvelasquez', 'nholland', 'michelle00', 'jerryyoung', 'gaustin', 'marissa82', 't
# ...

# %% [markdown]
# ### XML

# %% [markdown]
# 3.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`

# %%
import json
from bs4 import BeautifulSoup

with open('steps_sample.xml', 'r') as x:
    tableee = BeautifulSoup(x, 'xml')

recipes = tableee.find_all('recipe')
stepsd = {}

for recipe in recipes:
    recipe_id = recipe.find('id').text
    steps = [step.text for step in recipe.find('steps').find_all('step')]
    stepsd[recipe_id] = steps

stepsd

# %% [markdown]
# 3.2 По данным файла `steps_sample.xml` сформируйте словарь следующего вида: `кол-во_шагов_в_рецепте: [список_id_рецептов]`

# %%
dictt = dict()

for recipe in tableee.find_all('recipe'):
    opop = len([i for i in recipe.steps if i!='\n'])
    if opop in dictt:
        dictt[opop].append(recipe.id.text)
    else:
        dictt[opop] = []
print(dictt)
# Out:
# {11: ['302399', '375376', '140610', '374703', '111198', '257111', '432661', '114204', '63069', '165096', '33947', '250024', '330512', '315233', '25259', '331174', '407621', '263019', '112853', '383729', '13709', '336166', '143286', '387284', '290003', '370746', '34833', '11975', '426211', '373582', '88845', '456968', '14149', '507927', '73602', '91981', '175109', '390933', '193208', '83893', '243008', '259789', '303926', '410920', '446605', '32571', '74419', '308056', '78497', '111963', '361181', '302640', '356655', '53743', '57771', '420689', '74520', '50851', '176277', '266814', '27897', '189207', '138771', '279797', '177831', '32515', '256842', '95295', '383349', '109791', '332641', '116993', '173126', '187872', '177681', '249006', '314834', '283033', '117084', '49202', '284916', '247657', '313162', '424727', '227557', '431305', '263038', '439979', '443041', '241042', '258779', '66965', '200503', '109597', '503121', '290595', '401175', '169146', '282228', '316435', '248582', '5044
# ...

# %% [markdown]
# 3.3 Получите список рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов.

# %%
list_of_recipes = tableee.find_all('recipe')
res=[i.id.text for i in list_of_recipes if i.steps.find_all(attrs={'has_minutes':'1'}) or i.steps.find_all(attrs={'has_hours':'1'})]
print(res[:10])
# Out:
# ['44123', '35173', '453467', '306168', '50662', '118843', '149593', '200148', '310570', '95534']

# %% [markdown]
# 3.4 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений.

# %%
import numpy as np

rps = pd.read_csv("recipes_sample.csv", sep=',')   
for recipe in tableee.find_all("recipe"):
    id = int(recipe.find("id").text)
    if np.isnan(rps[rps["id"] == id]["n_steps"].values[0]): 
         rps.loc[rps.id == id, "n_steps"] = len(recipe.find_all("step"))
rps
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25     11.0
# 1               91970  2003-07-26      3.0
# ...

# %% [markdown]
# 3.5 Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`

# %%
if rps["n_steps"].isna().sum() == 0:
  rps["n_steps"] = rps["n_steps"].astype(np.int)
  rps.to_csv("recipes_sample_with_filled_nsteps.csv", index=False)
# Out:
# <ipython-input-40-50836b195160>:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rps["n_steps"] = rps["n_steps"].astype(np.int)

# %%
rswfn = pd.read_csv('recipes_sample_with_filled_nsteps.csv')
rswfn
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25       11
# 1               91970  2003-07-26        3
# ...
